# %% [markdown]
# <a href="https://colab.research.google.com/github/NaveedhAhmed-A/Clustering/blob/main/mall_customer_clustering_KMeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("/content/Mall_Customers.csv")
df.head()
# Out:
#    CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 0           1    Male   19                  15              39
# 1           2    Male   21                  15              81
# 2           3  Female   20                  16               6
# 3           4  Female   23                  16              77
# 4           5  Female   31                  17              40

# %%
encoder = LabelEncoder()
df['Genre'] = encoder.fit_transform(df['Genre'])
df.head()
# Out:
#    CustomerID  Genre  Age  Annual_Income_(k$)  Spending_Score
# 0           1      1   19                  15              39
# 1           2      1   21                  15              81
# 2           3      0   20                  16               6
# 3           4      0   23                  16              77
# 4           5      0   31                  17              40

# %%
x = df.drop(['CustomerID','Genre'],axis = 1)
x.head()
# Out:
#    Age  Annual_Income_(k$)  Spending_Score
# 0   19                  15              39
# 1   21                  15              81
# 2   20                  16               6
# 3   23                  16              77
# 4   31                  17              40

# %%
scalar = StandardScaler()
x_scaled = scalar.fit_transform(x)

# %%
wcss = []
for k in range(1,11):
  temp_model = KMeans(n_clusters = k,init='k-means++',random_state = 42)
  temp_model.fit(x_scaled)
  wcss.append(temp_model.inertia_)
plt.plot(range(1,11),wcss)

# %%
model = KMeans(n_clusters = 5,init = 'k-means++',random_state = 42)
model.fit(x_scaled)
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
df['cluster'] = model.predict(x_scaled)
df.head()
# Out:
#    CustomerID  Genre  Age  Annual_Income_(k$)  Spending_Score  cluster
# 0           1      1   19                  15              39        2
# 1           2      1   21                  15              81        2
# 2           3      0   20                  16               6        3
# 3           4      0   23                  16              77        2
# 4           5      0   31                  17              40        2
